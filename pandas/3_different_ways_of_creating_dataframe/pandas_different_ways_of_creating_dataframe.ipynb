# %% [markdown]
# # <font color="purple"><h3 align="center">Different Ways Of Creating Dataframe</h3></font>

# %% [markdown]
# ## <font color="green">Using csv</h3></font>

# %%
#!pip install xlrd
# Out:
# Collecting xlrd
#   Downloading https://files.pythonhosted.org/packages/07/e6/e95c4eec6221bfd8528bcc4ea252a850bffcc4be88ebc367e23a1a84b0bb/xlrd-1.1.0-py2.py3-none-any.whl (108kB)
# Installing collected packages: xlrd
# Successfully installed xlrd-1.1.0

# %%
import pandas as pd
df = pd.read_csv("weather_data.csv")
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# ## <font color="green">Using excel</h3></font>

# %%
df=pd.read_excel("weather_data.xlsx","Sheet1")
df
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01           32          6   ฝนตก
# 1 2017-01-02           35          7  Sunny
# 2 2017-01-03           28          2   Snow

# %% [markdown]
# ## <font color="green">Using dictionary</h3></font>

# %%
import pandas as pd
weather_data = {
    'day': ['1/1/2017','1/2/2017','1/3/2017'],
    'temperature': [32,35,28],
    'windspeed': [6,7,2],
    'event': ['Rain', 'Sunny', 'Snow']
}
df = pd.DataFrame(weather_data)
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# ## <font color="green">Using tuples list</h3></font>

# %%
weather_data = [
    ('1/1/2017',32,6,'Rain'),
    ('1/2/2017',35,7,'Sunny'),
    ('1/3/2017',28,2,'Snow')
]
df = pd.DataFrame(data=weather_data, columns=['day','temperature','windspeed','event'])
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# ## <font color="green">Using list of dictionaries</h3></font>

# %%
weather_data = [
    {'day': '1/1/2017', 'temperature': 32, 'windspeed': 6, 'event': 'Rain'},
    {'day': '1/2/2017', 'temperature': 35, 'windspeed': 7, 'event': 'Sunny'},
    {'day': '1/3/2017', 'temperature': 28, 'windspeed': 2, 'event': 'Snow'},
    
]
df = pd.DataFrame(data=weather_data, columns=['day','temperature','windspeed','event'])
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
df=pd.read_excel("excel.xlsx","Sheet1")
df
# Out:
#       ประเภทใบสั่ง ศูนย์งานหลัก        ใบสั่ง                      สถานะระบบ  \
# 0             ZPM4     GPTBOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# 1             ZPM4     GPTBOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# 2             ZPM4     GPTBOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# 3             ZPM4     GPTBOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# 4             ZPM4     GPTBOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# 5             ZPM4     GRSTOM01  4.003503e+09  CLSD PCNF GMCO MANC PRC  SETC
# 6             ZPM4     GTYIOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# 7             ZPM4     GTYIOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# 8             ZPM4     GTYIOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# 9             ZPM4     GTYIOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# 10            ZPM4     GTYIOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# 11            ZPM4     GTYIOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# 12            ZPM4     GTYIOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# 13            ZPM4     GTYIOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# 14            ZPM4     GTYIOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# 15            ZPM4     GTYIOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# 16            ZPM4     GTYIOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# 17            ZPM4     GTYIOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# 18            ZPM4     GTYIOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# 19            ZPM4     GTYIOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# 20            ZPM4     GTYIOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# 21            ZPM4     GTYIOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# 22            ZPM4     GPNIOM01  4.003503e+09            REL  MACM PRC  SETC
# 23            ZPM4     GTYIOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# 24            ZPM4     GTYIOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# 25            ZPM4     GTYIOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# 26            ZPM4     GTYIOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# 27            ZPM4     GTYIOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# 28            ZPM4     GTYIOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# 29            ZPM4     GTYIOM01  4.003503e+09       CLSD CNF  NMAT PRC  SETC
# ...            ...          ...           ...                            ...
# 40070         ZOM1     GTYIOM02  1.003695e+09  CLSD PCNF GMCO MANC PRC  SETC
# 40071         ZOM1     GTREOM02  1.003695e+09  CLSD PCNF GMCO MACM PRC  SETC
# 40072         ZOM1     GAPTOM02  1.003695e+09  REL  PCNF MANC NMAT PRC  SETC
# 40073         ZOM1     GRSTOM02  1.003695e+09  TECO PCNF GMCO MACM PRC  SETC
# 40074         ZOM1     GBINOM02  1.003695e+09  TECO PCNF MANC NMAT PRC  SETC
# 40075         ZOM1     GPBIOM02  1.003695e+09  CLSD PCNF GMCO MACM PRC  SETC
# 40076         ZOM1     GNNSCO11  1.003695e+09  CLSD PCNF GMCO MANC PRC  SETC
# 40077         ZOM1     GLLOOM02  1.003695e+09  CLSD PCNF GMCO MANC PRC  SETC
# 40078         ZOM1     GNNKOM02  1.003695e+09  CLSD CNF  GMCO MACM PRC  SETC
# 40079         ZOM1     GNNKOM02  1.003695e+09  CLSD CNF  GMCO MACM PRC  SETC
# 40080         ZOM1     GNNSCO11  1.003694e+09  CLSD PCNF GMCO MANC PRC  SETC
# 40081         ZOM1     GNNSCO11  1.003694e+09  CLSD PCNF GMCO MANC PRC  SETC
# 40082         ZOM1     GATGCY01  1.003694e+09  CLSD PCNF GMCO MANC PRC  SETC
# 40083         ZOM1     GPBIOM02  1.003694e+09       TECO PCNF NMAT PRC  SETC
# 40084         ZOM1     GLLOOM02  1.003694e+09  CLSD PCNF GMCO MANC PRC  SETC
# 40085         ZOM1     GLLOOM02  1.003694e+09  CLSD PCNF GMCO MANC PRC  SETC
# 40086         ZOM1     GLLAOM02  1.003694e+09  CLSD PCNF GMCO MACM PRC  SETC
# 40087         ZOM1     GLLAOM02  1.003694e+09  CLSD PCNF GMCO MACM PRC  SETC
# 40088         ZOM1     GKLGOM02  1.003694e+09  CLSD PCNF GMCO MANC PRC  SETC
# 40089         ZOM1     GKLGOM02  1.003694e+09  CLSD PCNF GMCO MANC PRC  SETC
# 40090         ZOM1     GKLGOM02  1.003694e+09  CLSD PCNF GMCO MANC PRC  SETC
# 40091         ZOM1     GKLGOM02  1.003694e+09  CLSD PCNF GMCO MANC PRC  SETC
# 40092         ZOM1     GSPOSM01  1.003694e+09       REL  PCNF MACM PRC  SETC
# 40093         ZOM1     GPBIOM02  1.003687e+09  CLSD PCNF GMCO MACM PRC  SETC
# 40094         ZOM1     GWCNCO11  1.003682e+09       TECO PCNF NMAT PRC  SETC
# 40095         ZOM1     GKBROM02  1.003679e+09  CLSD PCNF GMCO MACM PRC  SETC
# 40096         ZOM1     GNOKOM02  1.003673e+09       REL  PCNF NMAT PRC  SETC
# 40097         ZOM1     GLLOOM02  1.003671e+09  REL  PCNF MANC NMAT PRC  SETC
# 40098         ZOM1     GATGOM02  1.003641e+09  CLSD PCNF GMCO MANC PRC  SETC
# 40099          NaN          NaN           NaN                            NaN
#
#                                  ข้อความแบบสั้น สร้างเมื่อ     No  \
# 0                           งานตัดต้นไม้ BPN 09 2017-06-30      1
# 1                           งานตัดต้นไม้ BPN 07 2017-06-30      1
# 2                           งานตัดต้นไม้ BPN 04 2017-06-30      1
# 3                           งานตัดต้นไม้ BPN 02 2017-06-30      1
# 4                           งานตัดต้นไม้ BPN 01 2017-06-30      1
# 5      ทดลองติดตั้ง DF Barrier ในจุดที่มีเหตุกา 2017-06-30      1
# 6                          วัดโหลดหม้อแปลงปี 60 2017-06-30      1
# 7                          วัดโหลดหม้อแปลงปี 60 2017-06-30      1
# 8                          วัดโหลดหม้อแปลงปี 60 2017-06-30      1
# 9                          วัดโหลดหม้อแปลงปี 60 2017-06-30      1
# 10                         วัดโหลดหม้อแปลงปี 60 2017-06-30      1
# 11                         วัดโหลดหม้อแปลงปี 60 2017-06-30      1
# 12                         วัดโหลดหม้อแปลงปี 60 2017-06-30      1
# 13                         วัดโหลดหม้อแปลงปี 60 2017-06-30      1
# 14                         วัดโหลดหม้อแปลงปี 60 2017-06-30      1
# 15                         วัดโหลดหม้อแปลงปี 60 2017-06-30      1
# 16                         วัดโหลดหม้อแปลงปี 60 2017-06-30      1
# 17                         วัดโหลดหม้อแปลงปี 60 2017-06-30      1
# 18                         วัดโหลดหม้อแปลงปี 60 2017-06-30      1
# 19                         วัดโหลดหม้อแปลงปี 60 2017-06-30      1
# 20                         วัดโหลดหม้อแปลงปี 60 2017-06-30      1
# 21                         วัดโหลดหม้อแปลงปี 60 2017-06-30      1
# 22                ปรับปรุงระบบจำหน่ายซอยพยอม 20 2017-06-30      1
# 23                         วัดโหลดหม้อแปลงปี 60 2017-06-30      1
# 24                         วัดโหลดหม้อแปลงปี 60 2017-06-30      1
# 25                         วัดโหลดหม้อแปลงปี 60 2017-06-30      1
# 26                         วัดโหลดหม้อแปลงปี 60 2017-06-30      1
# 27                         วัดโหลดหม้อแปลงปี 60 2017-06-30      1
# 28                         วัดโหลดหม้อแปลงปี 60 2017-06-30      1
# 29                         วัดโหลดหม้อแปลงปี 60 2017-06-30      1
# ...                                         ...        ...    ...
# 40070                             DFตล.ฟิวส์ขาด 2017-12-01      1
# 40071                                 แยกวัดราม 2017-12-01      1
# 40072                         Priority: ด่วนมาก 2017-12-01      1
# 40073                         Priority: ด่วนมาก 2017-12-01      1
# 40074                         Priority: ปานกลาง 2017-12-01      1
# 40075            เปลี่ยนฟิวส์แรงสูงม.11 โนนห้อม 2017-12-01      1
# 40076                         Priority: ด่วนมาก 2017-12-01      1
# 40077                         Priority: ด่วนมาก 2017-12-01      1
# 40078                      ฟิวส์แรงต่ำขาด เฟส C 2017-12-01      1
# 40079                            ฟิวส์แรงต่ำขาด 2017-12-01      1
# 40080                             Priority: สูง 2017-12-01      1
# 40081                         Priority: ด่วนมาก 2017-12-01      1
# 40082                         Priority: ปานกลาง 2017-12-01      1
# 40083                   หลวมหัวเสาม.1ต.รอบเมือง 2017-12-01      1
# 40084                         Priority: ด่วนมาก 2017-12-01      1
# 40085                         Priority: ด่วนมาก 2017-12-01      1
# 40086                         Priority: ด่วนมาก 2017-12-01      1
# 40087                         Priority: ด่วนมาก 2017-12-01      1
# 40088                H.L.ชำรุด + อ็อกไซร์หัวเสา 2017-12-01      1
# 40089                         Priority: ด่วนมาก 2017-12-01      1
# 40090                                  DF.ชำรุด 2017-12-01      1
# 40091                                  LT ชำรุด 2017-12-01      1
# 40092                        หลวมหัวเสาโคกพนมดี 2017-12-01      1
# 40093                  ต่อสายขาด หน้าสวนพุทธรรม 2017-12-18      1
# 40094                         Priority: ด่วนมาก 2017-12-18      1
# 40095                         Priority: ด่วนมาก 2017-12-18      1
# 40096                         Priority: ด่วนมาก 2017-12-18      1
# 40097                         Priority: ด่วนมาก 2017-12-18      1
# 40098                         Priority: ปานกลาง 2017-12-18      1
# 40099                                       NaN        NaT  40099
#
#        Total act.costs กลุ่ม   กฟฟ      ...      โรงงาน  โรงงานซ่อมบำรุง  \
# 0         1.200180e+03   NaN  GPTB      ...        G060              NaN
# 1         1.200180e+03   NaN  GPTB      ...        G060              NaN
# 2         1.200180e+03   NaN  GPTB      ...        G060              NaN
# 3         1.200180e+03   NaN  GPTB      ...        G060              NaN
# 4         1.200180e+03   NaN  GPTB      ...        G060              NaN
# 5         2.174069e+05   NaN  GRST      ...        G080              NaN
# 6         9.551000e+01   NaN  GTYI      ...        G130              NaN
# 7         9.551000e+01   NaN  GTYI      ...        G130              NaN
# 8         9.551000e+01   NaN  GTYI      ...        G130              NaN
# 9         9.551000e+01   NaN  GTYI      ...        G130              NaN
# 10        2.175200e+02   NaN  GTYI      ...        G130              NaN
# 11        2.175200e+02   NaN  GTYI      ...        G130              NaN
# 12        2.175200e+02   NaN  GTYI      ...        G130              NaN
# 13        2.175200e+02   NaN  GTYI      ...        G130              NaN
# 14        9.551000e+01   NaN  GTYI      ...        G130              NaN
# 15        9.551000e+01   NaN  GTYI      ...        G130              NaN
# 16        9.551000e+01   NaN  GTYI      ...        G130              NaN
# 17        9.551000e+01   NaN  GTYI      ...        G130              NaN
# 18        2.175200e+02   NaN  GTYI      ...        G130              NaN
# 19        2.175200e+02   NaN  GTYI      ...        G130              NaN
# 20        2.175200e+02   NaN  GTYI      ...        G130              NaN
# 21        2.175200e+02   NaN  GTYI      ...        G130              NaN
# 22        0.000000e+00   NaN  GPNI      ...        G010              NaN
# 23        9.551000e+01   NaN  GTYI      ...        G130              NaN
# 24        9.551000e+01   NaN  GTYI      ...        G130              NaN
# 25        9.551000e+01   NaN  GTYI      ...        G130              NaN
# 26        9.551000e+01   NaN  GTYI      ...        G130              NaN
# 27        2.175200e+02   NaN  GTYI      ...        G130              NaN
# 28        2.175200e+02   NaN  GTYI      ...        G130              NaN
# 29        2.175200e+02   NaN  GTYI      ...        G130              NaN
# ...                ...   ...   ...      ...         ...              ...
# 40070     3.253500e+02   NaN  GTYI      ...        G130              NaN
# 40071     1.819000e+02   NaN  GTRE      ...        G110              NaN
# 40072     1.691300e+02   NaN  GAPT      ...        G070              NaN
# 40073     5.415520e+03   NaN  GRST      ...        G080              NaN
# 40074     3.013200e+02   NaN  GBIN      ...        G010             G010
# 40075     1.543740e+03   NaN  GPBI      ...        G040              NaN
# 40076     3.143870e+03   NaN  GNNS      ...        G130              NaN
# 40077     3.859400e+02   NaN  GLLO      ...        G060              NaN
# 40078     1.636200e+02   NaN  GNNK      ...        G050              NaN
# 40079     2.372800e+02   NaN  GNNK      ...        G050              NaN
# 40080     4.976000e+02   NaN  GNNS      ...        G130             G130
# 40081     1.734720e+03   NaN  GNNS      ...        G130              NaN
# 40082     1.818300e+02   NaN  GATG      ...        G020              NaN
# 40083     1.594200e+02   NaN  GPBI      ...        G040             G040
# 40084     2.709800e+02   NaN  GLLO      ...        G060             G060
# 40085     4.719500e+02   NaN  GLLO      ...        G060             G060
# 40086     1.462600e+02   NaN  GLLA      ...        G130             G130
# 40087     1.748500e+02   NaN  GLLA      ...        G130             G130
# 40088     9.987000e+02   NaN  GKLG      ...        G080              NaN
# 40089     2.528030e+03   NaN  GKLG      ...        G080             G080
# 40090     1.495690e+03   NaN  GKLG      ...        G080             G080
# 40091     8.150200e+02   NaN  GKLG      ...        G080             G080
# 40092     1.377200e+02   NaN  GSPO      ...        G040              NaN
# 40093     2.158900e+02   NaN  GPBI      ...        G040              NaN
# 40094     3.010000e+00   NaN  GWCN      ...        G020              NaN
# 40095     5.139110e+03   NaN  GKBR      ...        G120              NaN
# 40096     6.500000e+00   NaN  GNOK      ...        G030              NaN
# 40097     2.220600e+02   NaN  GLLO      ...        G060              NaN
# 40098     2.181600e+02   NaN  GATG      ...        G020              NaN
# 40099     1.161428e+08   NaN   NaN      ...         NaN              NaN
#
#       โรงงานที่วางแผน ใช้ได้ตั้งแต่  ใช้ได้ตั้งแต่.1 ใช้ได้ถึง ใช้ได้ถึงเวลา  \
# 0                G060           NaN         00:00:00       NaN      00:00:00
# 1                G060           NaN         00:00:00       NaN      00:00:00
# 2                G060           NaN         00:00:00       NaN      00:00:00
# 3                G060           NaN         00:00:00       NaN      00:00:00
# 4                G060           NaN         00:00:00       NaN      00:00:00
# 5                G080           NaN         00:00:00       NaN      00:00:00
# 6                G130           NaN         00:00:00       NaN      00:00:00
# 7                G130           NaN         00:00:00       NaN      00:00:00
# 8                G130           NaN         00:00:00       NaN      00:00:00
# 9                G130           NaN         00:00:00       NaN      00:00:00
# 10               G130           NaN         00:00:00       NaN      00:00:00
# 11               G130           NaN         00:00:00       NaN      00:00:00
# 12               G130           NaN         00:00:00       NaN      00:00:00
# 13               G130           NaN         00:00:00       NaN      00:00:00
# 14               G130           NaN         00:00:00       NaN      00:00:00
# 15               G130           NaN         00:00:00       NaN      00:00:00
# 16               G130           NaN         00:00:00       NaN      00:00:00
# 17               G130           NaN         00:00:00       NaN      00:00:00
# 18               G130           NaN         00:00:00       NaN      00:00:00
# 19               G130           NaN         00:00:00       NaN      00:00:00
# 20               G130           NaN         00:00:00       NaN      00:00:00
# 21               G130           NaN         00:00:00       NaN      00:00:00
# 22               G010           NaN         00:00:00       NaN      00:00:00
# 23               G130           NaN         00:00:00       NaN      00:00:00
# 24               G130           NaN         00:00:00       NaN      00:00:00
# 25               G130           NaN         00:00:00       NaN      00:00:00
# 26               G130           NaN         00:00:00       NaN      00:00:00
# 27               G130           NaN         00:00:00       NaN      00:00:00
# 28               G130           NaN         00:00:00       NaN      00:00:00
# 29               G130           NaN         00:00:00       NaN      00:00:00
# ...               ...           ...              ...       ...           ...
# 40070            G130           NaN         00:00:00       NaN      00:00:00
# 40071            G110           NaN         00:00:00       NaN      00:00:00
# 40072            G070           NaN         00:00:00       NaN      00:00:00
# 40073            G080           NaN         00:00:00       NaN      00:00:00
# 40074            G010           NaN         00:00:00       NaN      00:00:00
# 40075            G040           NaN         00:00:00       NaN      00:00:00
# 40076            G130           NaN         00:00:00       NaN      00:00:00
# 40077            G060           NaN         00:00:00       NaN      00:00:00
# 40078            G050           NaN         00:00:00       NaN      00:00:00
# 40079            G050           NaN         00:00:00       NaN      00:00:00
# 40080            G130           NaN         00:00:00       NaN      00:00:00
# 40081            G130           NaN         00:00:00       NaN      00:00:00
# 40082            G020           NaN         00:00:00       NaN      00:00:00
# 40083            G040           NaN         00:00:00       NaN      00:00:00
# 40084            G060           NaN         00:00:00       NaN      00:00:00
# 40085            G060           NaN         00:00:00       NaN      00:00:00
# 40086            G130           NaN         00:00:00       NaN      00:00:00
# 40087            G130           NaN         00:00:00       NaN      00:00:00
# 40088            G080           NaN         00:00:00       NaN      00:00:00
# 40089            G080           NaN         00:00:00       NaN      00:00:00
# 40090            G080           NaN         00:00:00       NaN      00:00:00
# 40091            G080           NaN         00:00:00       NaN      00:00:00
# 40092            G040           NaN         00:00:00       NaN      00:00:00
# 40093            G040           NaN         00:00:00       NaN      00:00:00
# 40094            G020           NaN         00:00:00       NaN      00:00:00
# 40095            G120           NaN         00:00:00       NaN      00:00:00
# 40096            G030           NaN         00:00:00       NaN      00:00:00
# 40097            G060           NaN         00:00:00       NaN      00:00:00
# 40098            G020           NaN         00:00:00       NaN      00:00:00
# 40099             NaN           NaN              NaN       NaN           NaN
#
#       ใบสั่งสูงกว่า  ใบสั่งหลัก    ใบแจ้งซ่อม
# 0               NaN         NaN           NaN
# 1               NaN         NaN           NaN
# 2               NaN         NaN           NaN
# 3               NaN         NaN           NaN
# 4               NaN         NaN           NaN
# 5               NaN         NaN           NaN
# 6               NaN         NaN           NaN
# 7               NaN         NaN           NaN
# 8               NaN         NaN           NaN
# 9               NaN         NaN           NaN
# 10              NaN         NaN           NaN
# 11              NaN         NaN           NaN
# 12              NaN         NaN           NaN
# 13              NaN         NaN           NaN
# 14              NaN         NaN           NaN
# 15              NaN         NaN           NaN
# 16              NaN         NaN           NaN
# 17              NaN         NaN           NaN
# 18              NaN         NaN           NaN
# 19              NaN         NaN           NaN
# 20              NaN         NaN           NaN
# 21              NaN         NaN           NaN
# 22              NaN         NaN           NaN
# 23              NaN         NaN           NaN
# 24              NaN         NaN           NaN
# 25              NaN         NaN           NaN
# 26              NaN         NaN           NaN
# 27              NaN         NaN           NaN
# 28              NaN         NaN           NaN
# 29              NaN         NaN           NaN
# ...             ...         ...           ...
# 40070           NaN         NaN  9.005326e+09
# 40071           NaN         NaN  9.005326e+09
# 40072           NaN         NaN  9.005326e+09
# 40073           NaN         NaN  9.005326e+09
# 40074           NaN         NaN  9.005326e+09
# 40075           NaN         NaN  9.005326e+09
# 40076           NaN         NaN  9.005326e+09
# 40077           NaN         NaN  9.005326e+09
# 40078           NaN         NaN  9.005326e+09
# 40079           NaN         NaN  9.005326e+09
# 40080           NaN         NaN  9.005326e+09
# 40081           NaN         NaN  9.005326e+09
# 40082           NaN         NaN  9.005326e+09
# 40083           NaN         NaN  9.005326e+09
# 40084           NaN         NaN  9.005326e+09
# 40085           NaN         NaN  9.005326e+09
# 40086           NaN         NaN  9.005326e+09
# 40087           NaN         NaN  9.005326e+09
# 40088           NaN         NaN  9.005326e+09
# 40089           NaN         NaN  9.005326e+09
# 40090           NaN         NaN  9.005326e+09
# 40091           NaN         NaN  9.005326e+09
# 40092           NaN         NaN  9.005326e+09
# 40093           NaN         NaN  9.005346e+09
# 40094           NaN         NaN  9.005346e+09
# 40095           NaN         NaN  9.005346e+09
# 40096           NaN         NaN  9.005346e+09
# 40097           NaN         NaN  9.005346e+09
# 40098           NaN         NaN  9.005346e+09
# 40099           NaN         NaN           NaN
#
# [40100 rows x 128 columns]

# %%
df['ใบสั่ง']
# Out:
# 0        4.003503e+09
# 1        4.003503e+09
# 2        4.003503e+09
# 3        4.003503e+09
# 4        4.003503e+09
# 5        4.003503e+09
# 6        4.003503e+09
# 7        4.003503e+09
# 8        4.003503e+09
# 9        4.003503e+09
# 10       4.003503e+09
# 11       4.003503e+09
# 12       4.003503e+09
# 13       4.003503e+09
# 14       4.003503e+09
# 15       4.003503e+09
# 16       4.003503e+09
# 17       4.003503e+09
# 18       4.003503e+09
# 19       4.003503e+09
# 20       4.003503e+09
# 21       4.003503e+09
# 22       4.003503e+09
# 23       4.003503e+09
# 24       4.003503e+09
# 25       4.003503e+09
# 26       4.003503e+09
# 27       4.003503e+09
# 28       4.003503e+09
# 29       4.003503e+09
#              ...
# 40070    1.003695e+09
# 40071    1.003695e+09
# 40072    1.003695e+09
# 40073    1.003695e+09
# 40074    1.003695e+09
# 40075    1.003695e+09
# 40076    1.003695e+09
# 40077    1.003695e+09
# 40078    1.003695e+09
# 40079    1.003695e+09
# 40080    1.003694e+09
# 40081    1.003694e+09
# 40082    1.003694e+09
# 40083    1.003694e+09
# 40084    1.003694e+09
# 40085    1.003694e+09
# 40086    1.003694e+09
# 40087    1.003694e+09
# 40088    1.003694e+09
# 40089    1.003694e+09
# 40090    1.003694e+09
# 40091    1.003694e+09
# 40092    1.003694e+09
# 40093    1.003687e+09
# 40094    1.003682e+09
# 40095    1.003679e+09
# 40096    1.003673e+09
# 40097    1.003671e+09
# 40098    1.003641e+09
# 40099             NaN
# Name: ใบสั่ง, Length: 40100, dtype: float64
